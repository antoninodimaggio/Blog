# %% [markdown]
# ---
# article : true
# author: "Antonino DiMaggio"
# date: 2020-10-01
# description: ""
# draft: false
# hasmath: true
# linktitle: "time series with scikit learn part1"
# tags:
#   - time series
#   - machine learning
# title: "Time Series with scikit-learn (Part I): Autoregressive Forecasting"
# ---

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd

mpl.rcParams['axes.labelsize'] = 20
mpl.rcParams['axes.titlesize'] = 24
mpl.rcParams['figure.figsize'] = (10, 6)
mpl.rcParams['xtick.labelsize'] = 14
mpl.rcParams['ytick.labelsize'] = 14
mpl.rcParams['legend.fontsize'] = 14

# %%
df = pd.read_csv('./data/pmj/COMED_hourly.csv', parse_dates=True, index_col='Datetime')
df.head()
# Out:
#                      COMED_MW
# Datetime
# 2011-12-31 01:00:00    9970.0
# 2011-12-31 02:00:00    9428.0
# 2011-12-31 03:00:00    9059.0
# 2011-12-31 04:00:00    8817.0
# 2011-12-31 05:00:00    8743.0

# %%
df.loc['2012-1':'2012-3'].plot(title='Hourly Demand Data')
plt.ylabel('Demand (MW)')
plt.show()
